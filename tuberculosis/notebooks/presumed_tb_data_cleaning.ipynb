# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt     
import seaborn as sns  
import missingno as msn   
import janitor
import re     
from dateutil import parser
# Install local package using "pip install -e . --config-setting editable_mode=compat"
import src  
from src.clean import load_data_and_dict       
from collections import Counter
import os
from dotenv import load_dotenv

# %%
# Load the west africa data 
load_dotenv() 

df = pd.read_excel(os.getenv('TBDATA_FILE_PATH'), sheet_name='PresumedTB -Program Grant')

# %%
def clean_column(val):
    if pd.isna(val):
        return val
    val = str(val).strip()
    try:
        parsed_date = parser.parse(val, fuzzy=False)
        return parsed_date.strftime('%Y-%m-%d')
    except (ValueError, TypeError):
        pass
    val = val.lower()
    if re.match(r"^\s*$|^_+$|^(n/a|na|null|none|unknown|\?)$", val, re.IGNORECASE):
        return pd.NA
    val = re.sub(r"\s+", "_", val)
    val = re.sub(r"[^a-z0-9_]", "", val)
    return val

def full_cleaning_pipeline(df):
    # Remove first part of column names and lowercase them
    df.columns = df.columns.str.split("_", n=1).str[-1].str.lower()
    
    # Combine age columns if they exist
    if 'ageyears' in df.columns and 'agemonths' in df.columns:
        df['age'] = df['ageyears'].combine_first(df['agemonths'] / 12)
        df = df.drop(columns=['ageyears', 'agemonths'])
    
    # Apply column cleaning
    df = df.apply(lambda col: col.map(clean_column) if col.dtype == 'object' else col)
    
    # Drop duplicates based on subjectid (lowercased)
    if 'subjectid' in df.columns:
        df = df.drop_duplicates(subset='subjectid')
    
    return df

# Apply pipeline
df = full_cleaning_pipeline(df)
display(df.head())
# Out:
#     dateseen subjectid  batchno adultindexcase patientinitials interviewer  \
# 0 2012-02-14    r10023        0         11j105              fs          sb
# 1 2012-02-14    r10025        0         11j105              ml          sb
# 2 2012-08-28    r10030        0     0102-11-09              bs          pj
# 3 2012-08-28    r10034        0     0102-11-09              mn          pj
# 4 2012-02-21    r10040        0         12p103              mm          sa
#
#       sex                       cough productive chestpain wheeze  \
# 0  female              cough__2_weeks         no       yes     no
# 1    male              cough__2_weeks        yes       yes     no
# 2    male               cough_3_weeks         no       yes     no
# 3    male                        <NA>         no       yes     no
# 4    male  no_cough_or_cough__2_weeks         no        no     no
#
#   fever_chills lossweight difficultbreathing nightsweats sidepain  \
# 0          yes         no                 no          no       no
# 1           no        yes                 no          no       no
# 2          yes        yes                 no          no      yes
# 3          yes        yes                 no         yes       no
# 4           no        yes                 no          no       no
#
#   malaise_fatigue lossappetite haemoptysis vomiting  numberepisode  \
# 0              no           no          no      yes            NaN
# 1              no          yes          no       no            NaN
# 2             yes          yes          no       no            NaN
# 3             yes           no          no      yes            NaN
# 4              no           no          no       no            NaN
#
#   pretbhistory othsymptom    bcgdate bcgscar         epiuptodate pallor  \
# 0          NaN        NaN        NaT     yes  card_not_available     no
# 1          NaN        NaN        NaT     yes           dont_know     no
# 2           no       <NA>        NaT      no  card_not_available     no
# 3           no       <NA>        NaT     yes  card_not_available    yes
# 4           no        NaN 2004-01-29     yes                 yes    yes
#
#   splenomegaly jaundice hepatomegaly wasting oedema clubbing irritability  \
# 0           no       no           no     yes     no       no           no
# 1           no       no           no      no     no       no           no
# 2           no       no           no      no     no       no           no
# 3           no       no           no     yes     no       no           no
# 4           no       no           no      no     no       no           no
#
#   dyspnoea deformityofspine lethargy abdominaldistension spasticity  \
# 0       no               no       no                  no         no
# 1       no               no       no                 yes         no
# 2       no               no       no                  no         no
# 3       no               no       no                  no         no
# 4       no               no       no                  no         no
#
#     specifysites lymphadenopathy  temperaturedc  pulsepm  \
# 0            NaN              no           36.5     88.0
# 1            NaN              no           36.4    104.0
# 2  cervical_15cm             yes           36.6    100.0
# 3  cervical_15cm             yes           35.9      NaN
# 4           <NA>              no           36.7     95.0
#
#                        otherclinicalsigns  respiratoryrate subcostalrecession  \
# 0                                    <NA>             32.0                 no
# 1                                    <NA>             28.0                 no
# 2                                    <NA>             24.0                 no
# 3  moluscum_lesions_popular_facial_rashes             22.0                 no
# 4                    viral_conjunctivitis             28.0                 no
#
#   dullness dullnesswhere crepitation crepitationwhere bronchialbreathing  \
# 0       no           NaN          no              NaN                yes
# 1       no           NaN          no              NaN                 no
# 2       no           NaN          no              NaN                 no
# 3       no           NaN         yes             both                 no
# 4       no           NaN          no              NaN                 no
#
#   bronchialbreathingwhere rhonchi rhonchiwhere reducedbreathsounds  \
# 0                    left     yes         both                  no
# 1                     NaN      no          NaN                 yes
# 2                     NaN      no          NaN                  no
# 3                     NaN      no          NaN                  no
# 4                     NaN      no          NaN                  no
#
#   reducedbreathsoundswhere other otherwhere  weightkg  heightcm  \
# 0                      NaN   NaN        NaN      21.2     124.0
# 1                     left  <NA>        NaN       NaN       NaN
# 2                      NaN  <NA>        NaN      15.3      99.5
# 3                      NaN  <NA>        NaN       7.1      72.4
# 4                      NaN  <NA>        NaN      23.9     124.0
#
#    of_circumferencecm  weightforage  weightforheight  heightforage  \
# 0                47.9           NaN              NaN           NaN
# 1                46.5           NaN              NaN           NaN
# 2                51.5         -0.42             0.06         -0.75
# 3                45.0         -3.39            -2.93         -2.79
# 4                 NaN           NaN              NaN           NaN
#
#    skinfoldthicknessmm  mua_circumferencemm  bmiforage chestxraydone  \
# 0                  NaN                 16.8        NaN           yes
# 1                  NaN                 15.0        NaN           yes
# 2                  NaN                 14.5        NaN           yes
# 3                  NaN                 12.0        NaN           yes
# 4                  NaN                 16.0        NaN           yes
#
#   chestxraydate      xrayquality xraynormal  xrayabnormaldescribe  \
# 0    2012-02-10     satisfactory         no                   NaN
# 1    2012-02-14  average_quality         no                   NaN
# 2    2012-08-28  average_quality         no                   NaN
# 3    2012-08-28     satisfactory         no                   NaN
# 4    2012-02-21     satisfactory         no                   NaN
#
#   lobarconsolidation lobarconsolidation_appa_r lobarconsolidation_appa_l  \
# 0                NaN                       NaN                       NaN
# 1                 no                       NaN                       NaN
# 2                 no                       NaN                       NaN
# 3                 no                       NaN                       NaN
# 4                 no                       NaN                       NaN
#
#    lobarconsolidation_lat_uz  lobarconsolidation_lat_lz bronchopneumonic  \
# 0                        NaN                        NaN               no
# 1                        NaN                        NaN               no
# 2                        NaN                        NaN               no
# 3                        NaN                        NaN               no
# 4                        NaN                        NaN               no
#
#   bronchopneumonic_appa_r bronchopneumonic_appa_l  bronchopneumonic_lat_uz  \
# 0                     NaN                     NaN                      NaN
# 1                     NaN                     NaN                      NaN
# 2                     NaN                     NaN                      NaN
# 3                     NaN                     NaN                      NaN
# 4                     NaN                     NaN                      NaN
#
#   bronchopneumonic_lat_lz perihilaradenopathy perihilaradenopathy_appa_r  \
# 0                     NaN                 yes                        yes
# 1                     NaN                  no                        NaN
# 2                     NaN                  no                        NaN
# 3                     NaN                 yes                        yes
# 4                     NaN                  no                        NaN
#
#   perihilaradenopathy_appa_l  perihilaradenopathy_lat_uz  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   perihilaradenopathy_lat_lz hyperinflation hyperinflation_appa_r  \
# 0                        NaN             no                   NaN
# 1                        NaN             no                   NaN
# 2                        NaN             no                   NaN
# 3                        NaN             no                   NaN
# 4                        NaN            yes                   yes
#
#   hyperinflation_appa_l  hyperinflation_lat_uz hyperinflation_lat_lz  \
# 0                   NaN                    NaN                   NaN
# 1                   NaN                    NaN                   NaN
# 2                   NaN                    NaN                   NaN
# 3                   NaN                    NaN                   NaN
# 4                   yes                    NaN                   NaN
#
#   interstitialchanges interstitialchanges_appa_r interstitialchanges_appa_l  \
# 0                  no                        NaN                        NaN
# 1                  no                        NaN                        NaN
# 2                  no                        NaN                        NaN
# 3                 yes                        NaN                        yes
# 4                  no                        NaN                        NaN
#
#    interstitialchanges_lat_uz  interstitialchanges_lat_lz nodularinfiltration  \
# 0                         NaN                         NaN                  no
# 1                         NaN                         NaN                  no
# 2                         NaN                         NaN                  no
# 3                         NaN                         NaN                  no
# 4                         NaN                         NaN                  no
#
#   nodularinfiltration_appa_r nodularinfiltration_appa_l  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    nodularinfiltration_lat_uz  nodularinfiltration_lat_lz  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   calcificationinthelung calcificationinthelung_appa_r  \
# 0                     no                           NaN
# 1                     no                           NaN
# 2                     no                           NaN
# 3                     no                           NaN
# 4                     no                           NaN
#
#   calcificationinthelung_appa_l  calcificationinthelung_lat_uz  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    calcificationinthelung_lat_lz fibrosis fibrosis_appa_r fibrosis_appa_l  \
# 0                            NaN       no             NaN             NaN
# 1                            NaN       no             NaN             NaN
# 2                            NaN       no             NaN             NaN
# 3                            NaN       no             NaN             NaN
# 4                            NaN       no             NaN             NaN
#
#    fibrosis_lat_uz  fibrosis_lat_lz cavity cavity_appa_r cavity_appa_l  \
# 0              NaN              NaN     no           NaN           NaN
# 1              NaN              NaN     no           NaN           NaN
# 2              NaN              NaN     no           NaN           NaN
# 3              NaN              NaN     no           NaN           NaN
# 4              NaN              NaN     no           NaN           NaN
#
#    cavity_lat_uz  cavity_lat_lz volumeloss volumeloss_appa_r  \
# 0            NaN            NaN         no               NaN
# 1            NaN            NaN         no               NaN
# 2            NaN            NaN         no               NaN
# 3            NaN            NaN         no               NaN
# 4            NaN            NaN         no               NaN
#
#   volumeloss_appa_l  volumeloss_lat_uz  volumeloss_lat_lz  \
# 0               NaN                NaN                NaN
# 1               NaN                NaN                NaN
# 2               NaN                NaN                NaN
# 3               NaN                NaN                NaN
# 4               NaN                NaN                NaN
#
#   perihilarinfiltration perihilarinfiltration_appa_r  \
# 0                    no                          NaN
# 1                   yes                          yes
# 2                   yes                          NaN
# 3                    no                          NaN
# 4                    no                          NaN
#
#   perihilarinfiltration_appa_l perihilarinfiltration_lat_uz  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    perihilarinfiltration_lat_lz paratrachealnodes paratrachealnodes_appa_r  \
# 0                           NaN                no                      NaN
# 1                           NaN               yes                      yes
# 2                           NaN                no                      NaN
# 3                           NaN                no                      NaN
# 4                           NaN               yes                      yes
#
#   paratrachealnodes_appa_l  paratrachealnodes_lat_uz  \
# 0                      NaN                       NaN
# 1                      yes                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
#    paratrachealnodes_lat_lz airwaycompression airwaycompression_appa_r  \
# 0                       NaN                no                      NaN
# 1                       NaN                no                      NaN
# 2                       NaN                no                      NaN
# 3                       NaN                no                      NaN
# 4                       NaN                no                      NaN
#
#   airwaycompression_appa_l  airwaycompression_lat_uz airwaycompression_lat_lz  \
# 0                      NaN                       NaN                      NaN
# 1                      NaN                       NaN                      NaN
# 2                      NaN                       NaN                      NaN
# 3                      NaN                       NaN                      NaN
# 4                      NaN                       NaN                      NaN
#
#   pleuralfluid pleuralfluid_appa_r pleuralfluid_appa_l  pleuralfluid_lat_uz  \
# 0           no                 NaN                 NaN                  NaN
# 1          NaN                 NaN                 NaN                  NaN
# 2           no                 NaN                 NaN                  NaN
# 3           no                 NaN                 NaN                  NaN
# 4           no                 NaN                 NaN                  NaN
#
#    pleuralfluid_lat_lz trachealdeviation softtissuechanges  \
# 0                  NaN               yes                no
# 1                  NaN               yes                no
# 2                  NaN                no                no
# 3                  NaN                no                no
# 4                  NaN                no                no
#
#   mediastinaldeviation spineabnormality cardiacabnormality  \
# 0                   no               no                 no
# 1                   no               no                 no
# 2                   no               no                 no
# 3                   no               no                 no
# 4                   no               no                 no
#
#   otherbonyabnormality otherbonyabnormality_specify displaceddiaphragm  \
# 0                   no                          NaN                 no
# 1                   no                          NaN                 no
# 2                   no                          NaN                 no
# 3                   no                          NaN                 no
# 4                   no                          NaN                 no
#
#             assessment assessment_note otherxraydiagnoses sputumsmear  \
# 0    abnormallikely_tb             NaN               <NA>         yes
# 1    abnormallikely_tb             NaN               <NA>         yes
# 2  abnormalunlikely_tb             NaN                NaN         yes
# 3    abnormallikely_tb             NaN               <NA>         yes
# 4    abnormallikely_tb             NaN               <NA>         NaN
#
#   sputumdate   sputumtype  genexpertresult cultureresult  othmycobacspecify  \
# 0 2012-02-16      induced  not_done_at_all      negative                NaN
# 1 2012-02-16  spontaneous  not_done_at_all      negative                NaN
# 2        NaT      induced         negative      negative                NaN
# 3        NaT      induced  not_done_at_all      negative                NaN
# 4        NaT  spontaneous  not_done_at_all      negative                NaN
#
#   othmicrobacwhenpos  othmicrobacwhenposdays skintestdone skintestdate  \
# 0                NaT                     NaN          yes   2012-02-11
# 1                NaT                     NaN          yes   2012-02-10
# 2                NaT                     NaN          yes   2012-02-17
# 3                NaT                     NaN          yes   2012-02-19
# 4                NaT                     NaN          yes   2012-02-17
#
#   skintestinduration  skintestdiametermm diagnosis eptbspecify  \
# 0                 no                 0.0    not_tb         NaN
# 1                yes                15.0    not_tb         NaN
# 2                 no                 NaN    not_tb         NaN
# 3                 no                 NaN    not_tb         NaN
# 4                yes                19.0    not_tb         NaN
#
#                                   nottbdiagnosis  tbscore antitbtreatment  \
# 0              lower_respiratory_tract_infection      7.0              no
# 1                                      viral_rti      7.0              no
# 2              upper_respiratory_track_infection      6.0              no
# 3  lower_respiratory_tract_infection_malnutition     12.0              no
# 4                                       virl_rti      6.0              no
#
#   treatmentplace treatmentstartdate treatmentid  \
# 0            NaN                NaT         NaN
# 1            NaN                NaT         NaN
# 2            NaN                NaT         NaN
# 3            NaN                NaT         NaN
# 4            NaN                NaT         NaN
#
#                                            otherplan  nextappointment  \
# 0          for_3_monthly_symptom_screening_follow_up              NaN
# 1  for_inh_prophylaxis_and_3_monthly_symtom_scree...              NaN
# 2                        3_monthly_symptom_screening              NaN
# 3                  for_inh_prophylaxis_and_follow_up              NaN
# 4                        3_monthly_symptom_screening              NaN
#
#   nextappointmentdate           entrydate       age
# 0                 NaT 2012-06-21 10:26:00  8.000000
# 1                 NaT 2012-05-31 13:26:00  2.166667
# 2                 NaT 2012-10-12 09:29:00  4.000000
# 3                 NaT 2012-10-12 09:24:00  1.250000
# 4                 NaT 2012-05-30 08:47:00  8.000000

# %%
# Inspect Missing Values
missing_values = df.isnull().sum()
missing_proportions = missing_values / len(df )
missing_df = pd.concat([missing_values, missing_proportions], axis=1)

missing_df.columns = ['Number of Missing Values', 'Proportion of Missing Values']
missing_df = missing_df.sort_values('Proportion of Missing Values', ascending=False)


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#display(missing_df)

# %%
# Mapping of second dataset columns
column_mapping = {
    "subjectid": "patient_id",
    "dateseen": "date_particip",
    "sex": "gender",
    "age": "age",
    "cough": "cough",
    "productive": "productive",
    "chestpain": "chest_pain",
    "wheeze": "wheeze",
    "fever_chills": "fever_chills",
    "lossweight": "loss_weight",
    "difficultbreathing": "difficulty_breathing",
    "nightsweats": "night_sweats",
    "sidepain": "side_pain",
    "lossappetite": "loss_appetite",
    "haemoptysis": "haemoptysis",
    "vomiting": "vomiting",
    "pretbhistory": "pretb_history",  
    "pallor": "pallor",
    "splenomegaly": "splenomegaly",
    "jaundice": "jaundice",
    "hepatomegaly": "hepatomegaly",
    "wasting": "wasting",
    "dyspnoea": "dyspnoea",
    "lethargy": "lethargy",
    "abdominaldistension": "abd_distension_mass",
    "lymphadenopathy": "neck_lymph",
    "temperaturedc": "temperature",
    "weightkg": "weight",
    "heightcm": "height",
    "mua_circumferencemm": "mua_circumference",
    "otherclinicalsigns": "other_clinical_sign",
    "respiratoryrate": "respiratory_rate",
    "subcostalrecession": "subscostal_rec",
    "dullness": "dullness",
    "crepitation": "crepitation",
    "bronchialbreathing": "bronchial_breathing",
    "rhonchi": "rhonchi",
    "reducedbreathsounds": "reduced_breath_sounds",
    "other": "other_abnorm",
    "assessment": "xray_assessment",
    "otherxraydiagnoses": "other_xray",
    "sputumtype": "sputum_type",
    "genexpertresult": "genexpert_result",
    "cultureresult": "mgit_result",
    "othmycobacspecify": "other_mycobactera",
    "diagnosis": "diagnosis",
    "eptbspecify": "eptb_site",
    "nottbdiagnosis": "nottb_diagnosis",
    "antitbtreatment": "antitb_treatment"
}

# Select and rename columns
df = df[list(column_mapping.keys())].rename(columns=column_mapping)

# %%
df.columns
# Out:
# Index(['patient_id', 'date_particip', 'gender', 'age', 'cough', 'productive',
#        'chest_pain', 'wheeze', 'fever_chills', 'loss_weight',
#        'difficulty_breathing', 'night_sweats', 'side_pain', 'loss_appetite',
#        'haemoptysis', 'vomiting', 'pretb_history', 'pallor', 'splenomegaly',
#        'jaundice', 'hepatomegaly', 'wasting', 'dyspnoea', 'lethargy',
#        'abd_distension_mass', 'neck_lymph', 'temperature', 'weight', 'height',
#        'mua_circumference', 'other_clinical_sign', 'respiratory_rate',
#        'subscostal_rec', 'dullness', 'crepitation', 'bronchial_breathing',
#        'rhonchi', 'reduced_breath_sounds', 'other_abnorm', 'xray_assessment',
#        'other_xray', 'sputum_type', 'genexpert_result', 'mgit_result',
#        'other_mycobactera', 'diagnosis', 'eptb_site', 'nottb_diagnosis',
#        'antitb_treatment'],
#       dtype='object')

# %% [markdown]
# `There are 8 columns that don't match: "malaise_fatigue", "date_previous_tb", "abnorm_site", "specimen_type", "spec_result", "histology_result", "hiv_serology", "country"`

# %%
# Inspect Missing Values
missing_values = df.isnull().sum()
missing_proportions = missing_values / len(df )
missing_df = pd.concat([missing_values, missing_proportions], axis=1)

missing_df.columns = ['Number of Missing Values', 'Proportion of Missing Values']
missing_df = missing_df.sort_values('Proportion of Missing Values', ascending=False)


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(missing_df)
# Out:
#                        Number of Missing Values  Proportion of Missing Values
# other_mycobactera                           924                      1.000000
# eptb_site                                   911                      0.985931
# other_abnorm                                864                      0.935065
# mgit_result                                 819                      0.886364
# other_clinical_sign                         702                      0.759740
# other_xray                                  592                      0.640693
# nottb_diagnosis                             209                      0.226190
# genexpert_result                            148                      0.160173
# pretb_history                                70                      0.075758
# sputum_type                                  67                      0.072511
# diagnosis                                    60                      0.064935
# antitb_treatment                             57                      0.061688
# mua_circumference                            50                      0.054113
# subscostal_rec                               44                      0.047619
# neck_lymph                                   44                      0.047619
# abd_distension_mass                          43                      0.046537
# splenomegaly                                 42                      0.045455
# hepatomegaly                                 42                      0.045455
# wasting                                      42                      0.045455
# dyspnoea                                     42                      0.045455
# lethargy                                     42                      0.045455
# pallor                                       41                      0.044372
# jaundice                                     41                      0.044372
# reduced_breath_sounds                        37                      0.040043
# rhonchi                                      36                      0.038961
# xray_assessment                              36                      0.038961
# bronchial_breathing                          36                      0.038961
# crepitation                                  36                      0.038961
# dullness                                     36                      0.038961
# cough                                        30                      0.032468
# respiratory_rate                             18                      0.019481
# temperature                                  17                      0.018398
# weight                                       16                      0.017316
# height                                       16                      0.017316
# gender                                       12                      0.012987
# chest_pain                                   10                      0.010823
# loss_appetite                                10                      0.010823
# vomiting                                     10                      0.010823
# night_sweats                                  9                      0.009740
# difficulty_breathing                          9                      0.009740
# loss_weight                                   8                      0.008658
# side_pain                                     8                      0.008658
# productive                                    8                      0.008658
# haemoptysis                                   7                      0.007576
# fever_chills                                  6                      0.006494
# wheeze                                        6                      0.006494
# age                                           6                      0.006494
# date_particip                                 0                      0.000000
# patient_id                                    0                      0.000000

# %%
df.shape
# Out:
# (924, 49)
